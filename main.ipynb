# %%
# !pip install -r "C:/Users/boole/git_projects/esg-data-integration-and-analytics/requirement.txt"

# %%
# !pip install numpy==1.22.4

# %% [markdown]
# ### Importing dependencies

# %%
# !pip install --upgrade scipy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
scores_df = pd.read_csv("C:/Users/boole/git_projects/esg-data-integration-and-analytics/scores.csv")
sp500_df = pd.read_csv("C:/Users/boole/git_projects/esg-data-integration-and-analytics/sp500_companies.csv")

# Display the first few rows of each dataframe
display(scores_df.head())
display(sp500_df.head())
# Out:
#   Ticker              Company  ESG Risk score  Environment Risk Score  \
# 0    AOS          A. O. Smith              25                     7.3
# 1    ABT               Abbott              25                     3.0
# 2   ABBV               AbbVie              28                     1.1
# 3    ACN            Accenture              10                     0.3
# 4   ATVI  Activision Blizzard              19                     0.2
#
#    Social Risk Score  Governance Risk Score  Controversy Level CDP Score  \
# 0               11.9                    6.3                  0         -
# 1               13.6                    8.4                  3         B
# 2               16.8                    9.9                  3         B
# 3                4.6                    4.8                  2         A
# 4               12.5                    6.3                  4         -
#
#    Sustainability Score                    title        quote current_price  \
# ...

# %%
scores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ticker                  502 non-null    object
#  1   Company                 502 non-null    object
#  2   ESG Risk score          502 non-null    int64
#  3   Environment Risk Score  502 non-null    float64
#  4   Social Risk Score       502 non-null    float64
#  5   Governance Risk Score   502 non-null    float64
#  6   Controversy Level       502 non-null    int64
#  7   CDP Score               502 non-null    object
#  8   Sustainability Score    502 non-null    int64
#  9   title                   502 non-null    object
#  10  quote                   502 non-null    object
#  11  current_price           500 non-null    object
#  12  day_range               502 non-null    object
#  13  year_range              502 non-null    object
# ...

# %%
sp500_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MMM         502 non-null    object
#  1   3M          502 non-null    object
#  2   Unnamed: 2  9 non-null      object
# dtypes: object(3)
# memory usage: 11.9+ KB
